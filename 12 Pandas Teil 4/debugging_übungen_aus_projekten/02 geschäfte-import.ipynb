# %%
import pandas as pd

# %%
df = pd.read_csv('geschäfte/2019.csv')

# %%
df
# Out:
#                                                  Titel     KRNr.  VorlagenNr.  \
# 0                                                  NaN       NaN          NaN
# 1    Wahl Mitglied der Kommission für Justiz und öf...    1/2019          NaN
# 2                  Keine Ladenöffnung am Berchtoldstag    6/2019          NaN
# 3         Standesinitiative ? Marschhalt beim E-Voting    2/2019          NaN
# 4                      Wahl Ersatzmitglied Obergericht    4/2019          NaN
# ..                                                 ...       ...          ...
# 476  Kasernenareal: Auch ein digitaler Leuchtturm f...  259/2019          NaN
# 477                    Anpassung des Jugendstrafrechts  352/2019          NaN
# 478         Wahl und Genehmigung Wahl Fachhochschulrat  214/2019          NaN
# 479  Planungs- und Baugesetz, Strassengesetz. Änder...       NaN       5533.0
# 480  Rettungsplan für die landwirtschaftliche Forsc...       NaN       5536.0
#
# ...
