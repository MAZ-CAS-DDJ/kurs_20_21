# %% [markdown]
# Importiere die requests Library

# %%
import requests

# %% [markdown]
# Importiere die Pandas Library in der Kurzform.

# %%
import pandas as pd

# %% [markdown]
# 1. Unter Verwendung der [USGS.gov Earthquake API](https://earthquake.usgs.gov/fdsnws/event/1/#parameters) ziehe heraus, wieviele Erdbeben sich im August 2018 ereignet haben?

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2020-08-01&endtime=2020-08-31')
r.text
# Out:
# '15388'

# %% [markdown]
# 2. Mache das gleiche für August 2019, 2018, 2017, 2016, 2015?

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2019-08-01&endtime=2019-08-31')
r.text
# Out:
# '19028'

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2018-08-01&endtime=2018-08-31')
r.text
# Out:
# '17045'

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2017-08-01&endtime=2017-08-31')
r.text
# Out:
# '12305'

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2016-08-01&endtime=2016-08-31')
r.text
# Out:
# '10922'

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2015-08-01&endtime=2015-08-31')
r.text
# Out:
# '9993'

# %%
startdates = ["2015-08-01", "2016-08-01","2017-08-01",
              "2018-08-01","2019-08-01", "2020-08-01"]
enddates = ["2015-08-31", "2016-08-31","2017-08-31",
              "2018-08-31","2019-08-31", "2020-08-31"]


baseurl = "https://earthquake.usgs.gov/fdsnws/event/1/count?starttime="
for start, end in zip(startdates, enddates):
    r = requests.get(baseurl + start + "&endtime=" + end)
    print(r.text)
# Out:
# 9993
# 10922
# 12305
# 17045
# 19028
# 15388

# %% [markdown]
# 3. Zeige nur die Erdbeben an, die in den letzten 5 Jahren eine Mindeststärke von 5,5 hatten? (Neue Parameter kannst Du mit den Zeichen "&" ergänzen. Lese Dich in die Dokumentation ein, um noch mehr Parameter kennezulernen)

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2015-01-01&endtime=2020-09-28&minmagnitude=5.5')
r.text
# Out:
# '2544'

# %% [markdown]
# 4. Zeige eine Liste der 10 stärksten Erdbeben des laufenden Jahres an. (Nicht vergessen, nun musst Du die Methode wechseln. Nicht mehr "count", sondern "query").

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-01-01&endtime=2020-09-28&minmagnitude=5.5')
ebs = r.json()
ebs
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1601355754000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-01-01&endtime=2020-09-28&minmagnitude=5.5',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 303},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '127 km SSW of Nikolski, Alaska',
#     'time': 1601179937392,
#     'updated': 1601353917294,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1tj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1tj&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.441,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 482,
#     'net': 'us',
#     'code': '6000c1tj',
#     'ids': ',at00qhaucg,us6000c1tj,ak020cg93eim,',
#     'sources': ',at,us,ak,',
#     'types': ',ground-failure,impact-link,losspager,moment-tensor,oaf,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.894,
#     'rms': 1.02,
#     'gap': 98,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 127 km SSW of Nikolski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-169.7665, 51.9341, 13.77]},
#    'id': 'us6000c1tj'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'south of Africa',
#     'time': 1601140222422,
#     'updated': 1601308660040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1np',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1np&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 572,
#     'net': 'us',
#     'code': '6000c1np',
#     'ids': ',us6000c1np,pt20270003,at00qh9zpe,',
#     'sources': ',us,pt,at,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 13.751,
#     'rms': 0.63,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - south of Africa'},
#    'geometry': {'type': 'Point', 'coordinates': [31.7636, -48.0314, 10]},
#    'id': 'us6000c1np'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': 'central Mid-Atlantic Ridge',
#     'time': 1600907269607,
#     'updated': 1600993907301,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0cs',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0cs&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '6000c0cs',
#     'ids': ',us6000c0cs,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 8.814,
#     'rms': 0.94,
#     'gap': 65,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - central Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-18.8285, -0.2758, 10]},
#    'id': 'us6000c0cs'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '21 km NW of Kultuk, Russia',
#     'time': 1600711497670,
#     'updated': 1601308420955,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzek',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzek&format=geojson',
#     'felt': 46,
#     'cdi': 6.8,
#     'mmi': 6.826,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 514,
#     'net': 'us',
#     'code': '6000bzek',
#     'ids': ',us6000bzek,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.204,
#     'rms': 0.68,
#     'gap': 28,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 21 km NW of Kultuk, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [103.48, 51.8574, 10]},
#    'id': 'us6000bzek'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': 'central East Pacific Rise',
#     'time': 1600695435082,
#     'updated': 1601216428974,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqr4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqr4&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000bqr4',
#     'ids': ',us7000bqr4,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 14.472,
#     'rms': 0.78,
#     'gap': 59,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - central East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.3789, -4.0426, 10]},
#    'id': 'us7000bqr4'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'central East Pacific Rise',
#     'time': 1600691277316,
#     'updated': 1600998105786,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqqu',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqqu&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000bqqu',
#     'ids': ',us7000bqqu,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 22.22,
#     'rms': 0.72,
#     'gap': 124,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - central East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.2161, -4.0832, 10]},
#    'id': 'us7000bqqu'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': '53 km E of Cortes, Philippines',
#     'time': 1600639995043,
#     'updated': 1600798473969,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bql2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bql2&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000bql2',
#     'ids': ',us7000bql2,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.436,
#     'rms': 0.52,
#     'gap': 45,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - 53 km E of Cortes, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.6798, 9.2631, 9]},
#    'id': 'us7000bql2'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': 'Mid-Indian Ridge',
#     'time': 1600549772268,
#     'updated': 1600701223040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqaf',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqaf&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.941,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000bqaf',
#     'ids': ',us7000bqaf,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.328,
#     'rms': 0.64,
#     'gap': 34,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - Mid-Indian Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [77.8605, -37.5627, 10]},
#    'id': 'us7000bqaf'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.9,
#     'place': 'central Mid-Atlantic Ridge',
#     'time': 1600465438936,
#     'updated': 1600639252455,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bq10',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bq10&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.454,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 732,
#     'net': 'us',
#     'code': '7000bq10',
#     'ids': ',pt20262001,at00qgvj1d,us7000bq10,',
#     'sources': ',pt,at,us,',
#     'types': ',impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 11.257,
#     'rms': 0.66,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.9 - central Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-26.8408, 0.9167, 10]},
#    'id': 'us7000bq10'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': '16 km E of Pýrgos, Greece',
#     'time': 1600446497464,
#     'updated': 1600757990267,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bpvt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bpvt&format=geojson',
#     'felt': 41,
#     'cdi': 4.2,
#     'mmi': 4.273,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 553,
#     'net': 'us',
#     'code': '7000bpvt',
#     'ids': ',us7000bpvt,pt20262000,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.463,
#     'rms': 0.7,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - 16 km E of Pýrgos, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.3313, 34.9972, 44.49]},
#    'id': 'us7000bpvt'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '260 km SSE of Alo, Wallis and Futuna',
#     'time': 1600362091966,
#     'updated': 1600875174243,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bphn',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bphn&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.118,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '7000bphn',
#     'ids': ',us7000bphn,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.349,
#     'rms': 0.87,
#     'gap': 92,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 260 km SSE of Alo, Wallis and Futuna'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.2625, -16.5187, 10]},
#    'id': 'us7000bphn'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'Banda Sea',
#     'time': 1600338745544,
#     'updated': 1600425389288,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bpbx',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bpbx&format=geojson',
#     'felt': 4,
#     'cdi': 3.1,
#     'mmi': 3.477,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 467,
#     'net': 'us',
#     'code': '7000bpbx',
#     'ids': ',us7000bpbx,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.264,
#     'rms': 1.28,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - Banda Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [129.3625, -6.7757, 182.77]},
#    'id': 'us7000bpbx'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': 'central Mid-Atlantic Ridge',
#     'time': 1600311617798,
#     'updated': 1600404033311,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bp8n',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bp8n&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '7000bp8n',
#     'ids': ',us7000bp8n,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 13.656,
#     'rms': 0.65,
#     'gap': 41,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - central Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-37.0393, 7.8718, 10]},
#    'id': 'us7000bp8n'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': 'southeast of the Loyalty Islands',
#     'time': 1600245870592,
#     'updated': 1600332511644,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bnvp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bnvp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '7000bnvp',
#     'ids': ',pt20260000,us7000bnvp,',
#     'sources': ',pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.329,
#     'rms': 0.84,
#     'gap': 64,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - southeast of the Loyalty Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [171.4996, -22.3257, 118.79]},
#    'id': 'us7000bnvp'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '160 km NNE of Labasa, Fiji',
#     'time': 1600143136407,
#     'updated': 1600229871864,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bndc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bndc&format=geojson',
#     'felt': 1,
#     'cdi': 5.2,
#     'mmi': 6.477,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '7000bndc',
#     'ids': ',us7000bndc,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.028,
#     'rms': 0.84,
#     'gap': 35,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 160 km NNE of Labasa, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [179.9438, -15.093, 10]},
#    'id': 'us7000bndc'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '15 km W of Esso, Russia',
#     'time': 1600141288012,
#     'updated': 1600315901155,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bnd1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bnd1&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.197,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 630,
#     'net': 'us',
#     'code': '7000bnd1',
#     'ids': ',us7000bnd1,pt20259000,at00qgokx3,',
#     'sources': ',us,pt,at,',
#     'types': ',ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.858,
#     'rms': 0.73,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 15 km W of Esso, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [158.4539, 55.9268, 344]},
#    'id': 'us7000bnd1'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': 'Vanuatu',
#     'time': 1599899667322,
#     'updated': 1601035870835,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bmcx',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bmcx&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 3.84,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 536,
#     'net': 'us',
#     'code': '7000bmcx',
#     'ids': ',us7000bmcx,pt20256002,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.857,
#     'rms': 0.7,
#     'gap': 64,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.6786, -17.2576, 10]},
#    'id': 'us7000bmcx'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '57 km SE of Ōfunato, Japan',
#     'time': 1599878650969,
#     'updated': 1600052462354,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bm9m',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bm9m&format=geojson',
#     'felt': 17,
#     'cdi': 4.3,
#     'mmi': 4.173,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 580,
#     'net': 'us',
#     'code': '7000bm9m',
#     'ids': ',us7000bm9m,at00qgiy9o,pt20256001,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.223,
#     'rms': 0.95,
#     'gap': 47,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 57 km SE of Ōfunato, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [142.2473, 38.7591, 32.09]},
#    'id': 'us7000bm9m'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '279 km E of Levuka, Fiji',
#     'time': 1599878249712,
#     'updated': 1599964867273,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bm9g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bm9g&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1.462,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '7000bm9g',
#     'ids': ',pt20256000,us7000bm9g,',
#     'sources': ',pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.553,
#     'rms': 1.1,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 279 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.0547, -17.8809, 556.57]},
#    'id': 'us7000bm9g'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '82 km NNE of Tocopilla, Chile',
#     'time': 1599809757195,
#     'updated': 1601028808654,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000blm2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000blm2&format=geojson',
#     'felt': 147,
#     'cdi': 6.8,
#     'mmi': 6.686,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 691,
#     'net': 'us',
#     'code': '7000blm2',
#     'ids': ',us7000blm2,at00qghh3w,pt20255000,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,ground-failure,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.076,
#     'rms': 0.87,
#     'gap': 72,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 82 km NNE of Tocopilla, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.9093, -21.3957, 51]},
#    'id': 'us7000blm2'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': '185 km SE of Sarangani, Philippines',
#     'time': 1599635920873,
#     'updated': 1599849737040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bk82',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bk82&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.501,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000bk82',
#     'ids': ',at00qgdqza,pt20253000,us7000bk82,',
#     'sources': ',at,pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.033,
#     'rms': 1.61,
#     'gap': 32,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - 185 km SE of Sarangani, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.6394, 4.2064, 18]},
#    'id': 'us7000bk82'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': '197 km SSE of Amahai, Indonesia',
#     'time': 1599525920952,
#     'updated': 1599612541271,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bjgb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bjgb&format=geojson',
#     'felt': 4,
#     'cdi': 3.1,
#     'mmi': 3.809,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 537,
#     'net': 'us',
#     'code': '7000bjgb',
#     'ids': ',us7000bjgb,pt20252000,at00qgbe3m,',
#     'sources': ',us,pt,at,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.173,
#     'rms': 0.78,
#     'gap': 12,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - 197 km SSE of Amahai, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [129.7627, -4.9124, 174.05]},
#    'id': 'us7000bjgb'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': 'Easter Island region',
#     'time': 1599500444171,
#     'updated': 1599841237144,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bjci',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bjci&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '7000bjci',
#     'ids': ',us7000bjci,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.5,
#     'rms': 1.1,
#     'gap': 34,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - Easter Island region'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9898, -24.512, 10]},
#    'id': 'us7000bjci'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': '64 km NNE of Port-Vila, Vanuatu',
#     'time': 1599460155325,
#     'updated': 1599546775273,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bj71',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bj71&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.63,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '7000bj71',
#     'ids': ',us7000bj71,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.106,
#     'rms': 1.1,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - 64 km NNE of Port-Vila, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [168.477, -17.1714, 10]},
#    'id': 'us7000bj71'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '73 km NNE of Port-Vila, Vanuatu',
#     'time': 1599459160093,
#     'updated': 1599633329105,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bj6y',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bj6y&format=geojson',
#     'felt': 3,
#     'cdi': 3.4,
#     'mmi': 6.226,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 555,
#     'net': 'us',
#     'code': '7000bj6y',
#     'ids': ',at00qg9yl1,pt20251000,us7000bj6y,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.039,
#     'rms': 1.35,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 73 km NNE of Port-Vila, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [168.476, -17.0893, 10]},
#    'id': 'us7000bj6y'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '17 km E of Talagutong, Philippines',
#     'time': 1599405823148,
#     'updated': 1599758261108,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000biyd',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000biyd&format=geojson',
#     'felt': 37,
#     'cdi': 7.2,
#     'mmi': 4.468,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 637,
#     'net': 'us',
#     'code': '7000biyd',
#     'ids': ',at00qg8tfl,pt20250007,us7000biyd,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.832,
#     'rms': 1.22,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 17 km E of Talagutong, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.8285, 6.2693, 120]},
#    'id': 'us7000biyd'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '128 km SE of Pangai, Tonga',
#     'time': 1599404119443,
#     'updated': 1599756551525,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000biy6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000biy6&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.228,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000biy6',
#     'ids': ',pt20250006,us7000biy6,',
#     'sources': ',pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.79,
#     'rms': 1.26,
#     'gap': 44,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 128 km SE of Pangai, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-173.5691, -20.7032, 10]},
#    'id': 'us7000biy6'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.7,
#     'place': 'central Mid-Atlantic Ridge',
#     'time': 1599375079004,
#     'updated': 1599489201287,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000biu8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000biu8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 691,
#     'net': 'us',
#     'code': '7000biu8',
#     'ids': ',pt20250004,at00qg85pi,us7000biu8,',
#     'sources': ',pt,at,us,',
#     'types': ',impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 22.623,
#     'rms': 0.74,
#     'gap': 39,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.7 - central Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-37.2174, 7.6929, 10]},
#    'id': 'us7000biu8'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '101 km NW of Port-Vila, Vanuatu',
#     'time': 1599361155559,
#     'updated': 1599534053041,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000birm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000birm&format=geojson',
#     'felt': 4,
#     'cdi': 5,
#     'mmi': 4.195,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 593,
#     'net': 'us',
#     'code': '7000birm',
#     'ids': ',pt20250002,at00qg7uyr,us7000birm,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,ground-failure,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.731,
#     'rms': 1.19,
#     'gap': 54,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 101 km NW of Port-Vila, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.5791, -17.1497, 8.24]},
#    'id': 'us7000birm'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '45 km NW of Ovalle, Chile',
#     'time': 1599355018930,
#     'updated': 1599679303178,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000biqb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000biqb&format=geojson',
#     'felt': 111,
#     'cdi': 5.1,
#     'mmi': 6.286,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 667,
#     'net': 'us',
#     'code': '7000biqb',
#     'ids': ',us7000biqb,at00qg7q8a,pt20250001,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.342,
#     'rms': 1.04,
#     'gap': 86,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 45 km NW of Ovalle, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.5642, -30.3355, 30.71]},
#    'id': 'us7000biqb'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': '133 km NW of Ternate, Indonesia',
#     'time': 1599351670819,
#     'updated': 1600228904268,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bipw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bipw&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 3.987,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 536,
#     'net': 'us',
#     'code': '7000bipw',
#     'ids': ',us7000bipw,pt20250000,at00qg7nne,',
#     'sources': ',us,pt,at,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.2,
#     'rms': 0.88,
#     'gap': 20,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - 133 km NW of Ternate, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5615, 1.6684, 30]},
#    'id': 'us7000bipw'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '11 km WSW of Finca Blanco, Panama',
#     'time': 1599241521829,
#     'updated': 1601052814048,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bi01',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bi01&format=geojson',
#     'felt': 19,
#     'cdi': 7.1,
#     'mmi': 6.053,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 496,
#     'net': 'us',
#     'code': '7000bi01',
#     'ids': ',us7000bi01,pt20248000,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.347,
#     'rms': 0.89,
#     'gap': 35,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 11 km WSW of Finca Blanco, Panama'},
#    'geometry': {'type': 'Point', 'coordinates': [-82.9722, 8.3579, 13.17]},
#    'id': 'us7000bi01'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': '94 km NW of Vallenar, Chile',
#     'time': 1598994557626,
#     'updated': 1599608987217,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bg4v',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bg4v&format=geojson',
#     'felt': 52,
#     'cdi': 5.3,
#     'mmi': 6.056,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 678,
#     'net': 'us',
#     'code': '7000bg4v',
#     'ids': ',us7000bg4v,at00qg003e,pt20245003,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.39,
#     'rms': 0.86,
#     'gap': 49,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.5 - 94 km NW of Vallenar, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3716, -27.9154, 14.52]},
#    'id': 'us7000bg4v'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': '100 km NW of Vallenar, Chile',
#     'time': 1598956312458,
#     'updated': 1601124849670,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfq3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfq3&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.376,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '7000bfq3',
#     'ids': ',us7000bfq3,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.44,
#     'rms': 0.74,
#     'gap': 131,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - 100 km NW of Vallenar, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.4003, -27.8702, 22]},
#    'id': 'us7000bfq3'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': '93 km NW of Vallenar, Chile',
#     'time': 1598943686283,
#     'updated': 1599030306291,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfmj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfmj&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.717,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '7000bfmj',
#     'ids': ',pt20245002,us7000bfmj,',
#     'sources': ',pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.384,
#     'rms': 1.51,
#     'gap': 70,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - 93 km NW of Vallenar, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.423, -27.9742, 20.58]},
#    'id': 'us7000bfmj'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '88 km NW of Vallenar, Chile',
#     'time': 1598938178874,
#     'updated': 1599024856694,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfld',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfld&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.974,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000bfld',
#     'ids': ',us7000bfld,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.331,
#     'rms': 0.69,
#     'gap': 136,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 88 km NW of Vallenar, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3367, -27.9671, 16.33]},
#    'id': 'us7000bfld'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': 'Near the coast of Atacama, Chile',
#     'time': 1598934602198,
#     'updated': 1600298958414,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfjx',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfjx&format=geojson',
#     'felt': 4,
#     'cdi': 4.5,
#     'mmi': 6.396,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 612,
#     'net': 'us',
#     'code': '7000bfjx',
#     'ids': ',us7000bfjx,pt20245001,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.25,
#     'rms': 0.97,
#     'gap': 69,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - Near the coast of Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.2874, -28.0385, 16.53]},
#    'id': 'us7000bfjx'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.8,
#     'place': '85 km NW of Vallenar, Chile',
#     'time': 1598933368731,
#     'updated': 1600639289114,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfjr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfjr&format=geojson',
#     'felt': 260,
#     'cdi': 5.4,
#     'mmi': 6.751,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 852,
#     'net': 'us',
#     'code': '7000bfjr',
#     'ids': ',at00qfyovo,pt20245000,us7000bfjr,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.307,
#     'rms': 0.85,
#     'gap': 69,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.8 - 85 km NW of Vallenar, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3031, -27.9728, 23]},
#    'id': 'us7000bfjr'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '65 km SW of Palana, Russia',
#     'time': 1598921477113,
#     'updated': 1599008230843,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfij',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfij&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.119,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000bfij',
#     'ids': ',us7000bfij,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.318,
#     'rms': 0.67,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 65 km SW of Palana, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [159.0051, 58.7546, 10]},
#    'id': 'us7000bfij'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': 'Tristan da Cunha region',
#     'time': 1598908682693,
#     'updated': 1599455885689,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfgl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfgl&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 536,
#     'net': 'us',
#     'code': '7000bfgl',
#     'ids': ',pt20244001,us7000bfgl,',
#     'sources': ',pt,us,',
#     'types': ',internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.122,
#     'rms': 1.05,
#     'gap': 31,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - Tristan da Cunha region'},
#    'geometry': {'type': 'Point', 'coordinates': [-15.6138, -35.4385, 10]},
#    'id': 'us7000bfgl'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': 'Pacific-Antarctic Ridge',
#     'time': 1598905688920,
#     'updated': 1599677818428,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bffs',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bffs&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000bffs',
#     'ids': ',us7000bffs,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 31.199,
#     'rms': 1.11,
#     'gap': 53,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - Pacific-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-130.1839, -54.9763, 10]},
#    'id': 'us7000bffs'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'Chagos Archipelago region',
#     'time': 1598894644946,
#     'updated': 1599595993905,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfbx',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfbx&format=geojson',
#     'felt': 7,
#     'cdi': 4.3,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 575,
#     'net': 'us',
#     'code': '7000bfbx',
#     'ids': ',us7000bfbx,pt20244000,at00qfxuzz,',
#     'sources': ',us,pt,at,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.041,
#     'rms': 1.28,
#     'gap': 22,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - Chagos Archipelago region'},
#    'geometry': {'type': 'Point', 'coordinates': [70.1973, -4.0158, 10]},
#    'id': 'us7000bfbx'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': 'central Mid-Atlantic Ridge',
#     'time': 1598822429757,
#     'updated': 1599776581234,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bf3k',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bf3k&format=geojson',
#     'felt': 2,
#     'cdi': 4.3,
#     'mmi': 4.817,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 651,
#     'net': 'us',
#     'code': '7000bf3k',
#     'ids': ',us7000bf3k,at00qfwba7,pt20243000,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 15.394,
#     'rms': 0.66,
#     'gap': 31,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.5 - central Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-29.8656, 0.7821, 10]},
#    'id': 'us7000bf3k'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '115 km NE of Maketu, New Zealand',
#     'time': 1598629625961,
#     'updated': 1600612200458,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000beek',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000beek&format=geojson',
#     'felt': 16,
#     'cdi': 4.6,
#     'mmi': 3.338,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 490,
#     'net': 'us',
#     'code': '7000beek',
#     'ids': ',us7000beek,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.106,
#     'rms': 1.05,
#     'gap': 138,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 115 km NE of Maketu, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [177.1884, -36.9075, 10]},
#    'id': 'us7000beek'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': 'Bouvet Island region',
#     'time': 1598581458132,
#     'updated': 1600983530676,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000be5j',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000be5j&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.826,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 518,
#     'net': 'us',
#     'code': '7000be5j',
#     'ids': ',us7000be5j,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 17.048,
#     'rms': 1.26,
#     'gap': 40,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - Bouvet Island region'},
#    'geometry': {'type': 'Point', 'coordinates': [1.5112, -54.7928, 10]},
#    'id': 'us7000be5j'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '141 km SSW of Kokopo, Papua New Guinea',
#     'time': 1598382532908,
#     'updated': 1600438593910,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bcty',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bcty&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.299,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 591,
#     'net': 'us',
#     'code': '7000bcty',
#     'ids': ',us7000bcty,pt20238005,',
#     'sources': ',us,pt,',
#     'types': ',ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.25,
#     'rms': 0.73,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 141 km SSW of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.8365, -5.5454, 22]},
#    'id': 'us7000bcty'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '145 km SSW of Kokopo, Papua New Guinea',
#     'time': 1598382281328,
#     'updated': 1600440352749,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bed1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bed1&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.105,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000bed1',
#     'ids': ',us7000bed1,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.28,
#     'rms': 0.84,
#     'gap': 41,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 145 km SSW of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.804, -5.5708, 10]},
#    'id': 'us7000bed1'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '141 km SSW of Kokopo, Papua New Guinea',
#     'time': 1598382178428,
#     'updated': 1600438421952,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bctq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bctq&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.965,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '7000bctq',
#     'ids': ',us7000bctq,pt20238004,',
#     'sources': ',us,pt,',
#     'types': ',ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.261,
#     'rms': 0.71,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 141 km SSW of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.8642, -5.5603, 23]},
#    'id': 'us7000bctq'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '10 km WNW of Papayal, Peru',
#     'time': 1598332691324,
#     'updated': 1600954521053,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bcgc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bcgc&format=geojson',
#     'felt': 17,
#     'cdi': 5.3,
#     'mmi': 5.106,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 474,
#     'net': 'us',
#     'code': '7000bcgc',
#     'ids': ',us7000bcgc,pt20238000,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.917,
#     'rms': 0.65,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 10 km WNW of Papayal, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8192, -4.0291, 28]},
#    'id': 'us7000bcgc'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '4 km SSW of Jacó, Costa Rica',
#     'time': 1598305869259,
#     'updated': 1601326484343,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bcbv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bcbv&format=geojson',
#     'felt': 106,
#     'cdi': 5.7,
#     'mmi': 5.362,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 614,
#     'net': 'us',
#     'code': '7000bcbv',
#     'ids': ',us7000bcbv,pt20237000,at00qfl8p6,',
#     'sources': ',us,pt,at,',
#     'types': ',dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.644,
#     'rms': 1.26,
#     'gap': 84,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 4 km SSW of Jacó, Costa Rica'},
#    'geometry': {'type': 'Point', 'coordinates': [-84.6376, 9.5785, 20]},
#    'id': 'us7000bcbv'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '81 km NNW of Hihifo, Tonga',
#     'time': 1598289295925,
#     'updated': 1600448137046,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bc4w',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bc4w&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.786,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '7000bc4w',
#     'ids': ',us7000bc4w,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.751,
#     'rms': 1.15,
#     'gap': 74,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 81 km NNW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-174.2169, -15.337, 10]},
# ...
#     'updated': 1585862898040,
#     'tz': 0,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006yla',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006yla&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '70006yla',
#     'ids': ',us70006yla,',
#     'sources': ',us,',
#     'types': ',geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 17.69,
#     'rms': 1.31,
#     'gap': 28,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 120km E of Bouvet Island, Bouvet Island'},
#    'geometry': {'type': 'Point', 'coordinates': [5.2056, -54.3946, 10]},
#    'id': 'us70006yla'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': '10km SSE of Indios, Puerto Rico',
#     'time': 1578747285910,
#     'updated': 1585862895040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020011010',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020011010&format=geojson',
#     'felt': 1331,
#     'cdi': 7.7,
#     'mmi': 6.598,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1420,
#     'net': 'pr',
#     'code': '2020011010',
#     'ids': ',pt20011058,us70006ydb,pr2020011010,',
#     'sources': ',pt,us,pr,',
#     'types': ',dyfi,general-text,geoserve,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 12,
#     'dmin': 0.1945,
#     'rms': 0.31,
#     'gap': 199,
#     'magType': 'mwp',
#     'type': 'earthquake',
#     'title': 'M 5.9 - 10km SSE of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8508, 17.949, 5]},
#    'id': 'pr2020011010'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '101km SSW of San Patricio, Mexico',
#     'time': 1578669681632,
#     'updated': 1585862890040,
#     'tz': -420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006xjw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006xjw&format=geojson',
#     'felt': 15,
#     'cdi': 3.4,
#     'mmi': 3.825,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 488,
#     'net': 'us',
#     'code': '70006xjw',
#     'ids': ',us70006xjw,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.64,
#     'rms': 0.97,
#     'gap': 102,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 101km SSW of San Patricio, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-105.2328, 18.4552, 10]},
#    'id': 'us70006xjw'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': 'Chukotskiy Avtonomnyy Okrug, Russia',
#     'time': 1578559088278,
#     'updated': 1585862876040,
#     'tz': 720,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006wuf',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006wuf&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.443,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 630,
#     'net': 'us',
#     'code': '70006wuf',
#     'ids': ',us70006wuf,',
#     'sources': ',us,',
#     'types': ',geoserve,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 6.048,
#     'rms': 0.77,
#     'gap': 21,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - Chukotskiy Avtonomnyy Okrug, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [171.0611, 62.358, 10]},
#    'id': 'us70006wuf'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'Pacific-Antarctic Ridge',
#     'time': 1578468581457,
#     'updated': 1585862872040,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006wd1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006wd1&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '70006wd1',
#     'ids': ',us70006wd1,',
#     'sources': ',us,',
#     'types': ',geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 32.289,
#     'rms': 1.21,
#     'gap': 69,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - Pacific-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-128.4311, -55.0203, 10]},
#    'id': 'us70006wd1'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '130km ENE of Kimbe, Papua New Guinea',
#     'time': 1578424295665,
#     'updated': 1584810804040,
#     'tz': 600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006vvr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006vvr&format=geojson',
#     'felt': 2,
#     'cdi': 3.1,
#     'mmi': 4.364,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 554,
#     'net': 'us',
#     'code': '70006vvr',
#     'ids': ',us70006vvr,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.346,
#     'rms': 1.03,
#     'gap': 22,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 130km ENE of Kimbe, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.2659, -5.2046, 117]},
#    'id': 'us70006vvr'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '8km SSW of Tallaboa, Puerto Rico',
#     'time': 1578395923540,
#     'updated': 1585942290671,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020007010',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020007010&format=geojson',
#     'felt': 195,
#     'cdi': 7.5,
#     'mmi': 6.611,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 796,
#     'net': 'pr',
#     'code': '2020007010',
#     'ids': ',us70006vpb,pr2020007010,',
#     'sources': ',us,pr,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 10,
#     'dmin': 0.171,
#     'rms': 0.08,
#     'gap': 177,
#     'magType': 'mwp',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 8km SSW of Tallaboa, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.776, 18.0223, 9]},
#    'id': 'pr2020007010'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '11km S of Tallaboa, Puerto Rico',
#     'time': 1578386041979,
#     'updated': 1584810789040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006vm9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006vm9&format=geojson',
#     'felt': 8,
#     'cdi': 5.9,
#     'mmi': 5.283,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 487,
#     'net': 'us',
#     'code': '70006vm9',
#     'ids': ',us70006vm9,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.186,
#     'rms': 1.25,
#     'gap': 40,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 11km S of Tallaboa, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7217, 17.8919, 10]},
#    'id': 'us70006vm9'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '13km S of Indios, Puerto Rico',
#     'time': 1578385465262,
#     'updated': 1601190786669,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006vll',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006vll&format=geojson',
#     'felt': 2565,
#     'cdi': 8.2,
#     'mmi': 7.569,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1820,
#     'net': 'us',
#     'code': '70006vll',
#     'ids': ',us70006vll,pt20007001,at00q3qa0q,pt20007009,pr2020007007,',
#     'sources': ',us,pt,at,pt,pr,',
#     'types': ',associate,dyfi,general-link,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,oaf,origin,phase-data,poster,shakemap,trump-origin,',
#     'nst': None,
#     'dmin': 0.117,
#     'rms': 0.64,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 13km S of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8266, 17.8686, 8.95]},
#    'id': 'us70006vll'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '14km S of Sinabang, Indonesia',
#     'time': 1578377119759,
#     'updated': 1584810788040,
#     'tz': 420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006vkq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006vkq&format=geojson',
#     'felt': 13,
#     'cdi': 6.5,
#     'mmi': 6.331,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 619,
#     'net': 'us',
#     'code': '70006vkq',
#     'ids': ',us70006vkq,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.599,
#     'rms': 0.97,
#     'gap': 33,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 14km S of Sinabang, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [96.3575, 2.3481, 17]},
#    'id': 'us70006vkq'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': '9km SE of Indios, Puerto Rico',
#     'time': 1578306738770,
#     'updated': 1584810787040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020006006',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020006006&format=geojson',
#     'felt': 936,
#     'cdi': 6.3,
#     'mmi': 6.356,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1240,
#     'net': 'pr',
#     'code': '2020006006',
#     'ids': ',pt20006001,us70006v7k,pr2020006006,',
#     'sources': ',pt,us,pr,',
#     'types': ',dyfi,general-text,geoserve,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 19,
#     'dmin': 0.1231,
#     'rms': 0.29,
#     'gap': 227,
#     'magType': 'mwp',
#     'type': 'earthquake',
#     'title': 'M 5.8 - 9km SE of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8193, 17.8675, 6]},
#    'id': 'pr2020006006'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': 'North of Ascension Island',
#     'time': 1578274160741,
#     'updated': 1584810796040,
#     'tz': -60,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006v42',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006v42&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '70006v42',
#     'ids': ',us70006v42,',
#     'sources': ',us,',
#     'types': ',geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 8.384,
#     'rms': 1.13,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - North of Ascension Island'},
#    'geometry': {'type': 'Point', 'coordinates': [-16.9866, 0.231, 10]},
#    'id': 'us70006v42'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.9,
#     'place': '4km N of Ixhuatan, Mexico',
#     'time': 1578199249332,
#     'updated': 1593798205028,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006uwq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006uwq&format=geojson',
#     'felt': 139,
#     'cdi': 5.9,
#     'mmi': 4.663,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 618,
#     'net': 'us',
#     'code': '70006uwq',
#     'ids': ',us70006uwq,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.783,
#     'rms': 1.14,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.9 - 4km N of Ixhuatan, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-94.489, 16.4011, 87]},
#    'id': 'us70006uwq'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '7km W of Santa Teresa, Nicaragua',
#     'time': 1578065334137,
#     'updated': 1584810796040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006u7m',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006u7m&format=geojson',
#     'felt': 62,
#     'cdi': 4.2,
#     'mmi': 3.486,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 491,
#     'net': 'us',
#     'code': '70006u7m',
#     'ids': ',us70006u7m,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.408,
#     'rms': 1.1,
#     'gap': 74,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 7km W of Santa Teresa, Nicaragua'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.2862, 11.7392, 106.87]},
#    'id': 'us70006u7m'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': '38km ENE of Hasaki, Japan',
#     'time': 1577989433135,
#     'updated': 1584810784040,
#     'tz': 540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006ttf',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006ttf&format=geojson',
#     'felt': 133,
#     'cdi': 4.5,
#     'mmi': 4.11,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 560,
#     'net': 'us',
#     'code': '70006ttf',
#     'ids': ',us70006ttf,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.912,
#     'rms': 1.03,
#     'gap': 61,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - 38km ENE of Hasaki, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [141.249, 35.8098, 31]},
#    'id': 'us70006ttf'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.6,
#     'place': '264km E of Baubau, Indonesia',
#     'time': 1577964304368,
#     'updated': 1584810783040,
#     'tz': 480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006thw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006thw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.741,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 482,
#     'net': 'us',
#     'code': '70006thw',
#     'ids': ',us70006thw,',
#     'sources': ',us,',
#     'types': ',geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.947,
#     'rms': 0.97,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.6 - 264km E of Baubau, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [124.976, -5.7527, 10]},
#    'id': 'us70006thw'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '81km SW of Taybad, Iran',
#     'time': 1577939346582,
#     'updated': 1591725178792,
#     'tz': 210,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006tev',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006tev&format=geojson',
#     'felt': 6,
#     'cdi': 4.8,
#     'mmi': 6.842,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 468,
#     'net': 'us',
#     'code': '70006tev',
#     'ids': ',us70006tev,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.655,
#     'rms': 0.91,
#     'gap': 45,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 81km SW of Taybad, Iran'},
#    'geometry': {'type': 'Point', 'coordinates': [60.2681, 34.1326, 10]},
#    'id': 'us70006tev'}],
#  'bbox': [-179.9464, -61.4129, 2.7, 179.9662, 85.729, 639.88]}

# %%
#Mit For Loop
for key in ebs:
    print(key)
# Out:
# type
# metadata
# features
# bbox

# %%
#Oder mit der .keys() Funktion
ebs.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
#Das sind alle Keys der Properties, die uns interessieren
ebs['features'][0]['properties'].keys()
# Out:
# dict_keys(['mag', 'place', 'time', 'updated', 'tz', 'url', 'detail', 'felt', 'cdi', 'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'code', 'ids', 'sources', 'types', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type', 'title'])

# %%
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    mag = eb['properties']['mag']
    maglst.append(mag)

# %%
maglst.sort()
maglst[-10:]
# Out:
# [6.9, 6.9, 6.9, 7, 7, 7.4, 7.4, 7.5, 7.7, 7.8]

# %% [markdown]
# 5. Wo haben sich diese Erdbeben ereignet?

# %%
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    if eb['properties']['mag'] > 6.89:
        mag = eb['properties']['mag']
        place = eb['properties']['place']
        minidict = {'Mag': mag,
                'Place': place}
        maglst.append(minidict)
    else:
        continue

# %%
pd.DataFrame(maglst)
# Out:
#    Mag                                       Place
# 0  6.9                  central Mid-Atlantic Ridge
# 1  6.9             221 km SSE of Katabu, Indonesia
# 2  6.9           122 km WSW of Bengkulu, Indonesia
# 3  7.8            100 km SSE of Perryville, Alaska
# 4  7.0  114 km NNW of Popondetta, Papua New Guinea
# 5  7.4       9 km SE of Santa María Xadani, Mexico
# 6  7.4               south of the Kermadec Islands
# 7  7.5        221km SSE of Severo-Kuril'sk, Russia
# 8  7.0                94km ENE of Kuril'sk, Russia
# 9  7.7                 123km NNW of Lucea, Jamaica

# %% [markdown]
# 6. Ziehe auch die Zeit mit heraus?

# %%
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    if eb['properties']['mag'] > 6.89:
        mag = eb['properties']['mag']
        place = eb['properties']['place']
        time = eb['properties']['time']
        minidict = {'Mag': mag,
                'Place': place,
                'Time': time}
        maglst.append(minidict)
    else:
        continue

# %% [markdown]
# 7. Konvertiere die Unix Zeit zu leserlichen Zeit? (Suche nicht zu lange, schau mal an, wies im Pandas aussieht.)

# %%
from datetime import datetime
ts = int("1564747406998")
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c39c18d595bb> in <module>
#       1 from datetime import datetime
#       2 ts = int("1564747406998")
# ----> 3 print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
#
# ValueError: year 51554 is out of range

# %%
#Das Problem sind die letzten drei Ziffer. Die Millisekunden. Sie müssen wir abschneiden.
ts = int("1564747406998"[:-3])
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2019-08-02 12:03:26

# %%
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    if eb['properties']['mag'] > 6.89:
        mag = eb['properties']['mag']
        place = eb['properties']['place']
        time = str(eb['properties']['time'])[:-3]
        time = datetime.utcfromtimestamp(int(time)).strftime('%y-%m-%d %H:%M:%S')
        minidict = {'Mag': mag,
                'Place': place,
                'Time': time}
        maglst.append(minidict)
    else:
        continue

# %%
#Sortieren wir die Tabelle (aber das werdet ihr am Mittwoch und Donnerstag genauer anschauen)
pd.DataFrame(maglst).sort_values(by='Time', ascending=False)
# Out:
#    Mag                                       Place               Time
# 0  6.9                  central Mid-Atlantic Ridge  20-09-18 21:43:58
# 1  6.9             221 km SSE of Katabu, Indonesia  20-08-21 04:09:52
# 2  6.9           122 km WSW of Bengkulu, Indonesia  20-08-18 22:29:24
# 3  7.8            100 km SSE of Perryville, Alaska  20-07-22 06:12:44
# 4  7.0  114 km NNW of Popondetta, Papua New Guinea  20-07-17 02:50:22
# 5  7.4       9 km SE of Santa María Xadani, Mexico  20-06-23 15:29:04
# 6  7.4               south of the Kermadec Islands  20-06-18 12:49:53
# 7  7.5        221km SSE of Severo-Kuril'sk, Russia  20-03-25 02:49:21
# 8  7.0                94km ENE of Kuril'sk, Russia  20-02-13 10:33:44
# 9  7.7                 123km NNW of Lucea, Jamaica  20-01-28 19:10:24

# %% [markdown]
# 8. Hole die 100 stärksten Erdbeben der letzten fünf Jahre und plotte sie auf Datawrapper

# %%
r = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2020-09-28&minmagnitude=5.5')
ebs = r.json()
ebs
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    mag = eb['properties']['mag']
    maglst.append(mag)

# %%
maglst.sort()
maglst[-100:]
# Out:
# [6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  6.9,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.2,
#  7.2,
#  7.2,
#  7.2,
#  7.2,
#  7.2,
#  7.3,
#  7.3,
#  7.3,
#  7.3,
#  7.3,
#  7.3,
#  7.3,
#  7.4,
#  7.4,
#  7.4,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.5,
#  7.6,
#  7.6,
#  7.6,
#  7.6,
#  7.7,
#  7.7,
#  7.7,
#  7.8,
#  7.8,
#  7.8,
#  7.8,
#  7.8,
#  7.8,
#  7.8,
#  7.9,
#  7.9,
#  7.9,
#  7.9,
#  8,
#  8.2,
#  8.2,
#  8.3]

# %%
ebs_details = ebs['features']
maglst = []
for eb in ebs_details:
    if eb['properties']['mag'] > 6.89:
        long = eb['geometry']['coordinates'][0]
        lat = eb['geometry']['coordinates'][1]
        mag = eb['properties']['mag']
        place = eb['properties']['place']
        time = str(eb['properties']['time'])[:-3]
        time = datetime.utcfromtimestamp(int(time)).strftime('%y-%m-%d %H:%M:%S')
        minidict = {'Mag': mag,
                'Place': place,
                'Time': time,
                'Long': long,
                'Lat': lat}
        maglst.append(minidict)
    else:
        continue

# %%
ebs['features'][0]['geometry']['coordinates']
# Out:
# [-169.7665, 51.9341, 13.77]

# %% [markdown]
# 9. Bilden wir funktionen
