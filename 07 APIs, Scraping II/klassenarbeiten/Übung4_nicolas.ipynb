# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.24heures.ch/')
content = r.text
soup = BeautifulSoup(content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="fr">
#  <head>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <link href="https://feed-prod.unitycms.io" rel="preconnect"/>
#   <link href="https://feed-prod.unitycms.io" rel="dns-prefetch"/>
#   <link href="https://tdn.da-services.ch" rel="preconnect"/>
#   <link href="https://tdn.da-services.ch" rel="dns-prefetch"/>
#   <link href="https://fonts.gstatic.com/" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com/" rel="dns-prefetch"/>
#   <link href="https://fonts.googleapis.com/" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/" rel="dns-prefetch"/>
#   <link href="https://astronomixus.prod.tda.link/" rel="preconnect"/>
#   <link href="https://astronomixus.prod.tda.link/" rel="dns-prefetch"/>
#   <link href="https://beagle.prod.tda.link/" rel="preconnect"/>
#   <link href="https://beagle.prod.tda.link/" rel="dns-prefetch"/>
#   <link href="https://tpc.googlesyndication.com/" rel="preconnect"/>
# ...

# %%
titre=soup.find_all('span', {'ArticleTeaser_title__1Xvn1'})

# %%
titre[0]
# Out:
# <span class="ArticleTeaser_title__1Xvn1">La crise du Covid-19 a coûté 31 millions à la Ville de Lausanne</span>

# %%
commentaires1=soup.find_all('span', {'class':'ArticleTeaserMeta_comm'})
