# %%
#import camelot
import tabula
import pandas as pd

# %% [markdown]
# ### Die Dokumentation ist hier

# %% [markdown]
# Hier ist die Dokumentation von [Camelot](https://camelot-py.readthedocs.io/en/master/). Und hier diejenige von [Tabula](https://pypi.org/project/tabula-py/).

# %% [markdown]
# ### Wir arbeiten mit den Unfällen

# %%
df = tabula.read_pdf('Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf', pages='all')

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1                 Unnamed: 2  Unnamed: 3  \
# 0        NaN         NaN  Unfälle mit\rSach-schaden         NaN
# 1      Total         NaN                      2 489         NaN
# 2    Aarberg         NaN                         26         NaN
# 3  Aarwangen         NaN                         10         NaN
# 4  Adelboden         NaN                          8         NaN
#
#                         Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0  Unfälle mit\rPersonen-\rschaden         NaN   Getötete         NaN
# 1                            2 397         NaN         34         NaN
# 2                               12         NaN          0         NaN
# 3                               15         NaN          0         NaN
# 4                               11         NaN          1         NaN
#
#            Unnamed: 8  Unnamed: 9                            davon  \
# 0  Schwer-\rverletzte         NaN  lebens-\rbedrohlich\rVerletzte1
# 1                 506         NaN                               30
# 2                   2         NaN                                0
# 3                   2         NaN                                0
# 4                   3         NaN                                0
#
#    Unnamed: 11            Unnamed: 12  Unnamed: 13       Unnamed: 14
# 0          NaN  erheblich\rVerletzte1          NaN  Leicht-verletzte
# 1          NaN                    476          NaN             2 344
# 2          NaN                      2          NaN                15
# 3          NaN                      2          NaN                14
# 4          NaN                      3          NaN                 9

# %%
df2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")

# %%
df2.head()
# Out:
#   اسمي سلطانمرحباً\rمن اين انت؟انا من ولاية كارولينا الشمال\r1234عندي 47 قطط\rاسمي Jeremy في الانجليزيةهل انت شباك؟\rJeremy is جرمي in Arabic  \
# 0                                             مرحباً
# 1                       انا من ولاية كارولينا الشمال
# 2                                               1234
# 3                                       هل انت شباك؟
# 4                           Jeremy is جرمي in Arabic
#
#                   Unnamed: 1
# 0                 اسمي سلطان
# 1                من اين انت؟
# 2                عندي 47 قطط
# 3  اسمي Jeremy في الانجليزية
# 4                        NaN

# %% [markdown]
# [Tabula Dokumentation](https://tabula-py.readthedocs.io/en/latest/faq.html#tabula-py-does-not-work)

# %% [markdown]
# [How to grab the PDF coordinates.](https://github.com/tabulapdf/tabula-java/wiki/Using-the-command-line-tabula-extractor-tool#grab-coordinates-of-the-table-you-want)

# %%
df = tabula.read_pdf('Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf', area=(114.0,50.0,779.88,561.128))

# %%
df
# Out:
#                Unnamed: 0 Unfälle mit\rSach-schaden  \
# 0                   Total                     2 489
# 1                 Aarberg                        26
# 2               Aarwangen                        10
# 3               Adelboden                         8
# 4                Aefligen                         0
# 5                Aegerten                         3
# 6        Aeschi bei Spiez                         9
# 7   Affoltern im Emmental                         3
# 8             Alchenstorf                         1
# 9            Allmendingen                         5
# 10            Amsoldingen                         2
# 11                   Arch                         1
# 12              Arni (BE)                         2
# 13               Attiswil                         2
# 14                 Auswil                         1
# 15                Bannwil                         1
# 16            Bargen (BE)                         2
# 17               Bäriswil                         1
# 18           Bätterkinden                         4
# 19             Beatenberg                         4
# 20               Bellmund                         1
# 21                   Belp                        25
# 22              Belprahon                         1
# 23                 Berken                         0
# 24                   Bern                       353
# 25           Bettenhausen                         2
# 26            Biel/Bienne                       196
# 27                 Biglen                         1
# 28             Bleienbach                         5
# 29            Blumenstein                         0
# 30               Bolligen                        13
# 31               Boltigen                        14
# 32                Bönigen                         4
# 33                  Bowil                         2
# 34    Bremgarten bei Bern                         3
# 35            Brenzikofen                         1
# 36            Brienz (BE)                         7
# 37            Brienzwiler                         3
# 38                  Brügg                        16
# 39              Brüttelen                         0
# 40         Buchholterberg                         1
# 41               Büetigen                         2
# 42                   Bühl                         1
# 43      Büren an der Aare                         4
# 44               Burgdorf                        48
# 45             Burgistein                         4
# 46   Busswil bei Melchnau                         0
# 47                Champoz                         0
# 48            Clavaleyres                         0
# 49         Corcelles (BE)                         3
# 50              Corgémont                         2
#
#    Unfälle mit\rPersonen-\rschaden  Getötete  Schwer-\rverletzte  \
# 0                            2 397        34                 506
# 1                               12         0                   2
# 2                               15         0                   2
# 3                               11         1                   3
# 4                                0         0                   0
# 5                                3         0                   0
# 6                                6         0                   2
# 7                                4         0                   0
# 8                                1         0                   0
# 9                                3         0                   2
# 10                               0         0                   0
# 11                               2         0                   0
# 12                               1         0                   0
# 13                               1         0                   0
# 14                               0         0                   0
# 15                               1         0                   1
# 16                               4         0                   0
# 17                               3         0                   0
# 18                               6         0                   0
# 19                               4         0                   0
# 20                               0         0                   0
# 21                              30         0                   5
# 22                               0         0                   0
# 23                               1         0                   1
# 24                             345         5                  69
# 25                               1         0                   0
# 26                             201         1                  23
# 27                               1         0                   1
# 28                               2         0                   0
# 29                               4         0                   2
# 30                               7         0                   2
# 31                              12         0                   5
# 32                               2         0                   3
# 33                               5         1                   2
# 34                               1         0                   0
# 35                               0         0                   0
# 36                               6         0                   2
# 37                               8         1                   5
# 38                              14         0                   1
# 39                               4         0                   3
# 40                               2         0                   0
# 41                               0         0                   0
# 42                               1         0                   0
# 43                               8         0                   1
# 44                              48         2                   7
# 45                               1         0                   1
# 46                               0         0                   0
# 47                               0         0                   0
# 48                               0         0                   0
# 49                               0         0                   0
# 50                               5         0                   1
#
#     lebens-\rbedrohlich\rVerletzte1  erheblich\rVerletzte1 Leicht-verletzte  \
# 0                                30                    476            2 344
# 1                                 0                      2               15
# 2                                 0                      2               14
# 3                                 0                      3                9
# 4                                 0                      0                0
# 5                                 0                      0                4
# 6                                 0                      2                5
# 7                                 0                      0                4
# 8                                 0                      0                2
# 9                                 0                      2                1
# 10                                0                      0                0
# 11                                0                      0                2
# 12                                0                      0                1
# 13                                0                      0                1
# 14                                0                      0                0
# 15                                0                      1                0
# 16                                0                      0                4
# 17                                0                      0                5
# 18                                0                      0                7
# 19                                0                      0                5
# 20                                0                      0                0
# 21                                0                      5               27
# 22                                0                      0                0
# 23                                0                      1                0
# 24                                7                     62              333
# 25                                0                      0                1
# 26                                1                     22              193
# 27                                0                      1                0
# 28                                0                      0                2
# 29                                1                      1                3
# 30                                0                      2                5
# 31                                0                      5               16
# 32                                0                      3                3
# 33                                0                      2                4
# 34                                0                      0                1
# 35                                0                      0                0
# 36                                1                      1                6
# 37                                0                      5                4
# 38                                0                      1               15
# 39                                0                      3                3
# 40                                0                      0                8
# 41                                0                      0                0
# 42                                0                      0                1
# 43                                0                      1                7
# 44                                0                      7               45
# 45                                0                      1                0
# 46                                0                      0                0
# 47                                0                      0                0
# 48                                0                      0                0
# 49                                0                      0                0
# 50                                0                      1                4
#
#     Unnamed: 8
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN

# %% [markdown]
# ### Wir arbeiten mit den Unfällen

# %%
#Kein Resultat 
tables = camelot.read_pdf('Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf', pages = "1") 
tables
#Ansteuern können wir die Tabelle auch mit der url selber:
#https://www.police.be.ch/police/de/index/ueber-uns/kantonspolizei/statistik/Verkehrsstatistik.assetref/dam/documents/POM/Police/de/Statistik/Bericht_110%20ohne%20AB_AS%20Gemeinden-Stand%202018%20%28D%29.pdf
# Out:
# <TableList n=0>

# %%
#Kein Resultat
tables = camelot.read_pdf('Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf', flavor='lattice', pages = "1") 
tables
# Out:
# <TableList n=0>

# %%
#Resultat, hurrah!
tables = camelot.read_pdf('Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf', flavor='stream', pages = "1") 
tables
# Out:
# <TableList n=1>

# %%
#hmm, Aber nur mit einer unvollständigen Tabelle :-/
tables[0].df
# Out:
#                                 0             1            2         3  \
# 0  nach Unfallfolgen und Gemeinde
# 1
# 2                                                Unfälle mit
# 3                                   Unfälle mit    Personen-
# 4                                  Sach-schaden      schaden  Getötete
# 5                           Total         2 489        2 397        34
# 6                         Aarberg            26           12         0
# 7                       Aarwangen            10           15         0
# 8                       Adelboden             8           11         1
# 9                        Aefligen             0            0         0
#
#            4           5           6                 7
# 0
# 1                  davon
# 2                lebens-
# 3    Schwer-  bedrohlich   erheblich
# 4  verletzte  Verletzte¹  Verletzte¹  Leicht-verletzte
# 5        506          30         476             2 344
# 6          2           0           2                15
# 7          2           0           2                14
# 8          3           0           3                 9
# 9          0           0           0                 0

# %%
#Wir müssen dem Code sagen, wo er überall nachschauen muss. Nämlich auf der ganzen Seite.
tables_stream = camelot.read_pdf("Bericht_110 ohne AB_AS Gemeinden-Stand 2018 (D).pdf", flavor='stream', pages='all', table_areas=['0,842,595,0'])

# %%
tables_stream[0].df
# Out:
#                                  0  \
# 0
# 1                             2018
# 2          Unfälle und Verunfallte
# 3   nach Unfallfolgen und Gemeinde
# 4
# 5
# 6
# 7
# 8                            Total
# 9                          Aarberg
# 10                       Aarwangen
# 11                       Adelboden
# 12                        Aefligen
# 13                        Aegerten
# 14                Aeschi bei Spiez
# 15           Affoltern im Emmental
# 16                     Alchenstorf
# 17                    Allmendingen
# 18                     Amsoldingen
# 19                            Arch
# 20                       Arni (BE)
# 21                        Attiswil
# 22                          Auswil
# 23                         Bannwil
# 24                     Bargen (BE)
# 25                        Bäriswil
# 26                    Bätterkinden
# 27                      Beatenberg
# 28                        Bellmund
# 29                            Belp
# 30                       Belprahon
# 31                          Berken
# 32                            Bern
# 33                    Bettenhausen
# 34                     Biel/Bienne
# 35                          Biglen
# 36                      Bleienbach
# 37                     Blumenstein
# 38                        Bolligen
# 39                        Boltigen
# 40                         Bönigen
# 41                           Bowil
# 42             Bremgarten bei Bern
# 43                     Brenzikofen
# 44                     Brienz (BE)
# 45                     Brienzwiler
# 46                           Brügg
# 47                       Brüttelen
# 48                  Buchholterberg
# 49                        Büetigen
# 50                            Bühl
# 51               Büren an der Aare
# 52                        Burgdorf
# 53                      Burgistein
# 54            Busswil bei Melchnau
# 55                         Champoz
# 56                     Clavaleyres
# 57                  Corcelles (BE)
# 58                       Corgémont
#
#                                                  1            2         3  \
# 0   Übersicht: Gemeinde ohne Autobahn, Autostrasse
# 1
# 2
# 3
# 4
# 5                                                   Unfälle mit
# 6                                      Unfälle mit    Personen-
# 7                                     Sach-schaden      schaden  Getötete
# 8                                            2 489        2 397        34
# 9                                               26           12         0
# 10                                              10           15         0
# 11                                               8           11         1
# 12                                               0            0         0
# 13                                               3            3         0
# 14                                               9            6         0
# 15                                               3            4         0
# 16                                               1            1         0
# 17                                               5            3         0
# 18                                               2            0         0
# 19                                               1            2         0
# 20                                               2            1         0
# 21                                               2            1         0
# 22                                               1            0         0
# 23                                               1            1         0
# 24                                               2            4         0
# 25                                               1            3         0
# 26                                               4            6         0
# 27                                               4            4         0
# 28                                               1            0         0
# 29                                              25           30         0
# 30                                               1            0         0
# 31                                               0            1         0
# 32                                             353          345         5
# 33                                               2            1         0
# 34                                             196          201         1
# 35                                               1            1         0
# 36                                               5            2         0
# 37                                               0            4         0
# 38                                              13            7         0
# 39                                              14           12         0
# 40                                               4            2         0
# 41                                               2            5         1
# 42                                               3            1         0
# 43                                               1            0         0
# 44                                               7            6         0
# 45                                               3            8         1
# 46                                              16           14         0
# 47                                               0            4         0
# 48                                               1            2         0
# 49                                               2            0         0
# 50                                               1            1         0
# 51                                               4            8         0
# 52                                              48           48         2
# 53                                               4            1         0
# 54                                               0            0         0
# 55                                               0            0         0
# 56                                               0            0         0
# 57                                               3            0         0
# 58                                               2            5         0
#
#             4           5           6                 7
# 0
# 1
# 2
# 3
# 4                   davon
# 5                 lebens-
# 6     Schwer-  bedrohlich   erheblich
# 7   verletzte  Verletzte¹  Verletzte¹  Leicht-verletzte
# 8         506          30         476             2 344
# 9           2           0           2                15
# 10          2           0           2                14
# 11          3           0           3                 9
# 12          0           0           0                 0
# 13          0           0           0                 4
# 14          2           0           2                 5
# 15          0           0           0                 4
# 16          0           0           0                 2
# 17          2           0           2                 1
# 18          0           0           0                 0
# 19          0           0           0                 2
# 20          0           0           0                 1
# 21          0           0           0                 1
# 22          0           0           0                 0
# 23          1           0           1                 0
# 24          0           0           0                 4
# 25          0           0           0                 5
# 26          0           0           0                 7
# 27          0           0           0                 5
# 28          0           0           0                 0
# 29          5           0           5                27
# 30          0           0           0                 0
# 31          1           0           1                 0
# 32         69           7          62               333
# 33          0           0           0                 1
# 34         23           1          22               193
# 35          1           0           1                 0
# 36          0           0           0                 2
# 37          2           1           1                 3
# 38          2           0           2                 5
# 39          5           0           5                16
# 40          3           0           3                 3
# 41          2           0           2                 4
# 42          0           0           0                 1
# 43          0           0           0                 0
# 44          2           1           1                 6
# 45          5           0           5                 4
# 46          1           0           1                15
# 47          3           0           3                 3
# 48          0           0           0                 8
# 49          0           0           0                 0
# 50          0           0           0                 1
# 51          1           0           1                 7
# 52          7           0           7                45
# 53          1           0           1                 0
# 54          0           0           0                 0
# 55          0           0           0                 0
# 56          0           0           0                 0
# 57          0           0           0                 0
# 58          1           0           1                 4

# %% [markdown]
# ## Datenbereinigung

# %%
# Nun müssen alle Tabelln zusammengeführt werden. Aber wie soll eine einzelne aussehen?
test_df = tables_stream[3].df

# %%
test_df[9:].head()
# Out:
#                       0   1   2  3  4  5  6   7
# 9            Langenthal  35  46  1  7  0  7  50
# 10  Langnau im Emmental  17  19  2  2  0  2  17
# 11              Lauenen   1   0  0  0  0  0   0
# 12               Laupen  12   5  0  0  0  0   6
# 13           Lauperswil   4  10  0  2  1  1  13

# %%
#Ab der 8 Zeile
data = test_df[9:]

# %%
headers = ['Gemeinde', 'Sachschaden', 'Personenschaden', 'Getötete', 
           'Schwerverletzte', 'Lebensbedrohlich Verletzte', 
           'Erheblich Verletzte', 'Leichtverletzte']

# %%
data.columns = headers

# %% [markdown]
# ### Und nun hängen wir alls zusammen

# %%
#eine leere df bauen
ff = pd.DataFrame()
headers = ['Gemeinde', 'Sachschaden', 'Personenschaden', 'Getötete', 
           'Schwerverletzte', 'Lebensbedrohlich Verletzte', 
           'Erheblich Verletzte', 'Leichtverletzte']

#Und nun durch alles iterieren
#https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
for number in range(0,8):
    temp = tables_stream[number].df #
    temp = temp[9:]
    temp.columns = headers
    ff = pd.concat([ff, temp])

# %%
ff.describe()
# Out:
#           Gemeinde Sachschaden Personenschaden Getötete Schwerverletzte  \
# count          347         347             347      347             347
# unique         347          36              35        5              16
# top     Kernenried           0               0        0               0
# freq             1          71              71      319             175
#
#        Lebensbedrohlich Verletzte Erheblich Verletzte Leichtverletzte
# count                         347                 347             347
# unique                          5                  14              37
# top                             0                   0               0
# freq                          324                 179              92

# %%
ff.dtypes
# Out:
# Gemeinde                      object
# Sachschaden                   object
# Personenschaden               object
# Getötete                      object
# Schwerverletzte               object
# Lebensbedrohlich Verletzte    object
# Erheblich Verletzte           object
# Leichtverletzte               object
# dtype: object

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 9 to 55
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gemeinde                    347 non-null    object
#  1   Sachschaden                 347 non-null    object
#  2   Personenschaden             347 non-null    object
#  3   Getötete                    347 non-null    object
#  4   Schwerverletzte             347 non-null    object
#  5   Lebensbedrohlich Verletzte  347 non-null    object
#  6   Erheblich Verletzte         347 non-null    object
#  7   Leichtverletzte             347 non-null    object
# dtypes: object(8)
# memory usage: 24.4+ KB

# %%
## Mit leeren Strings umgehen
def clean(elem):
    if elem == "":
        return 0
    else:
        return elem
ff = ff.applymap(clean)

# %%
## Die Gemeinden zwischenzeitlich löschen und dann wieder reinnehmen bei der Umwandlung in Zahlen
gem = ff['Gemeinde'] 
del ff['Gemeinde']
ff = ff.astype(int)
ff['Gemeinde'] = gem
ff = ff[['Gemeinde', 'Sachschaden', 'Personenschaden', 'Getötete', 
           'Schwerverletzte', 'Lebensbedrohlich Verletzte', 
           'Erheblich Verletzte', 'Leichtverletzte']].copy() ##Reihenfolge

# %%
ff = ff.reset_index()

# %%
#index anpassen
ff = ff.reset_index()
del ff['index']

# %%
ff
# Out:
#      level_0                                           Gemeinde  Sachschaden  \
# 0          0                                            Aarberg           26
# 1          1                                          Aarwangen           10
# 2          2                                          Adelboden            8
# 3          3                                           Aefligen            0
# 4          4                                           Aegerten            3
# ..       ...                                                ...          ...
# 342      342                                         Zollikofen           21
# 343      343                                        Zuzwil (BE)            0
# 344      344                                         Zweisimmen            6
# 345      345                                        Zwieselberg            1
# 346      346  ¹ Zahlen für lebensbedrohlich Verletzte und er...            0
#
#      Personenschaden  Getötete  Schwerverletzte  Lebensbedrohlich Verletzte  \
# 0                 12         0                2                           0
# 1                 15         0                2                           0
# 2                 11         1                3                           0
# 3                  0         0                0                           0
# 4                  3         0                0                           0
# ..               ...       ...              ...                         ...
# 342               15         1                4                           0
# 343                0         0                0                           0
# 344                5         1                1                           1
# 345                1         0                1                           0
# 346                0         0                0                           0
#
#      Erheblich Verletzte  Leichtverletzte
# 0                      2               15
# 1                      2               14
# 2                      3                9
# 3                      0                0
# 4                      0                4
# ..                   ...              ...
# 342                    4               10
# 343                    0                0
# 344                    0                4
# 345                    1                0
# 346                    0                0
#
# [347 rows x 9 columns]

# %%
ff.sort_values(by='Sachschaden', ascending=False)
# Out:
#      level_0                                           Gemeinde  Sachschaden  \
# 23        23                                               Bern          353
# 25        25                                        Biel/Bienne          196
# 292      292                                               Thun          129
# 141      141                                              Köniz           78
# 43        43                                           Burgdorf           48
# ..       ...                                                ...          ...
# 178      178                                          Merzligen            0
# 177      177                                           Melchnau            0
# 160      160                                             Ligerz            0
# 148      148                                          Landiswil            0
# 346      346  ¹ Zahlen für lebensbedrohlich Verletzte und er...            0
#
#      Personenschaden  Getötete  Schwerverletzte  Lebensbedrohlich Verletzte  \
# 23               345         5               69                           7
# 25               201         1               23                           1
# 292              138         0               26                           2
# 141               71         0               11                           1
# 43                48         2                7                           0
# ..               ...       ...              ...                         ...
# 178                1         0                0                           0
# 177                3         0                0                           0
# 160                2         0                1                           0
# 148                2         0                0                           0
# 346                0         0                0                           0
#
#      Erheblich Verletzte  Leichtverletzte
# 23                    62              333
# 25                    22              193
# 292                   24              135
# 141                   10               64
# 43                     7               45
# ..                   ...              ...
# 178                    0                1
# 177                    0                3
# 160                    1                1
# 148                    0                3
# 346                    0                0
#
# [347 rows x 9 columns]
